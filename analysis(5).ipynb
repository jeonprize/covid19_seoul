# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False)
plt.style.use("fivethirtyeight")

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
df = pd.read_csv("seoul_covid19.csv")
df
# Out:
#           연번     환자         확진일  거주지 여행력                   접촉력 조치상황     년월  \
# 0      24267  78369  2021-01-31  타시도   -              감염경로 조사중  치료중  21-01
# 1      24266  78472  2021-01-31  강남구   -              감염경로 조사중  치료중  21-01
# 2      24265  78484  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 3      24264  78471  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 4      24263  78415  2021-01-31  타시도   -            타시도 확진자 접촉  치료중  21-01
# ...      ...    ...         ...  ...  ..                   ...  ...    ...
# 24262      5      9  2020-01-31  성북구   -             기타 확진자 접촉   퇴원  20-01
# 24263      4      7  2020-01-30  마포구  중국                  해외유입   퇴원  20-01
# 24264      3      6  2020-01-30  종로구   -              종로구 집단발병   퇴원  20-01
# 24265      2      5  2020-01-30  중랑구  중국                  해외유입   퇴원  20-01
# 24266      1      2  2020-01-24  강서구  중국                  해외유입   퇴원  20-01
#
#             년월일  월  주      년주
# 0      21-01-31  1  4  2021-4
# 1      21-01-31  1  4  2021-4
# 2      21-01-31  1  4  2021-4
# 3      21-01-31  1  4  2021-4
# 4      21-01-31  1  4  2021-4
# ...         ... .. ..     ...
# 24262  20-01-31  1  5  2020-5
# 24263  20-01-30  1  5  2020-5
# 24264  20-01-30  1  5  2020-5
# 24265  20-01-30  1  5  2020-5
# 24266  20-01-24  1  4  2020-4
#
# [24267 rows x 12 columns]

# %%
df["거주지"].unique()
# Out:
# array(['타시도', '강남구', '광진구', '용산구', '기타', '동대문구', '성동구', '서초구', '영등포구',
#        '중구', '양천구', '강서구', '금천구', '노원구', '관악구', '동작구', '중랑구', '구로구',
#        '성북구', '마포구', '강동구', '송파구', '강북구', '도봉구', '서대문구', '종로구', '은평구',
#        '강서구 ', '서대문구 ', ' 은평구', ' 송파구', '성동구 ', '중랑구 ', '관악구 ', '성북구 ',
#        '동대문구 ', '노원구 ', '동작구 ', '은평구 ', '서초구 ', '강북구 ', '용산구 ', '구로구 ',
#        '마포구 ', '영등포구 ', '강동구 ', '중구 ', '종로구 ', '송파구 ', '양천구 ', '은평구   ',
#        '금천구 ', '광진구 ', '도봉구 ', '강남구 ', '타시도 ', ' 관악구 ', ' 도봉구 ', ' 노원구 ',
#        ' 성동구'], dtype=object)

# %%
df["타지역"] = df["거주지"].str.contains("기타") + df["거주지"].str.contains("타시도") + df["거주지"].str.contains("내발산동") 
df
# Out:
# C:\Users\SANGMIN\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:194: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   op=op_str, alt_op=unsupported[op_str]
#           연번     환자         확진일  거주지 여행력                   접촉력 조치상황     년월  \
# 0      24267  78369  2021-01-31  타시도   -              감염경로 조사중  치료중  21-01
# 1      24266  78472  2021-01-31  강남구   -              감염경로 조사중  치료중  21-01
# 2      24265  78484  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 3      24264  78471  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 4      24263  78415  2021-01-31  타시도   -            타시도 확진자 접촉  치료중  21-01
# ...      ...    ...         ...  ...  ..                   ...  ...    ...
# 24262      5      9  2020-01-31  성북구   -             기타 확진자 접촉   퇴원  20-01
# 24263      4      7  2020-01-30  마포구  중국                  해외유입   퇴원  20-01
# 24264      3      6  2020-01-30  종로구   -              종로구 집단발병   퇴원  20-01
# 24265      2      5  2020-01-30  중랑구  중국                  해외유입   퇴원  20-01
# 24266      1      2  2020-01-24  강서구  중국                  해외유입   퇴원  20-01
#
#             년월일  월  주      년주    타지역
# 0      21-01-31  1  4  2021-4   True
# 1      21-01-31  1  4  2021-4  False
# 2      21-01-31  1  4  2021-4  False
# 3      21-01-31  1  4  2021-4  False
# 4      21-01-31  1  4  2021-4   True
# ...         ... .. ..     ...    ...
# 24262  20-01-31  1  5  2020-5  False
# 24263  20-01-30  1  5  2020-5  False
# 24264  20-01-30  1  5  2020-5  False
# 24265  20-01-30  1  5  2020-5  False
# 24266  20-01-24  1  4  2020-4  False
#
# [24267 rows x 13 columns]

# %%
df["퇴원"] = df["조치상황"].str.contains("퇴원")
df["사망"] = df["조치상황"].str.contains("사망")
df["병원"] = df["조치상황"].str.contains("치료중")
df
# Out:
#           연번     환자         확진일  거주지 여행력                   접촉력 조치상황     년월  \
# 0      24267  78369  2021-01-31  타시도   -              감염경로 조사중  치료중  21-01
# 1      24266  78472  2021-01-31  강남구   -              감염경로 조사중  치료중  21-01
# 2      24265  78484  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 3      24264  78471  2021-01-31  강남구   -  성동구 소재 병원 관련('21.1월)  치료중  21-01
# 4      24263  78415  2021-01-31  타시도   -            타시도 확진자 접촉  치료중  21-01
# ...      ...    ...         ...  ...  ..                   ...  ...    ...
# 24262      5      9  2020-01-31  성북구   -             기타 확진자 접촉   퇴원  20-01
# 24263      4      7  2020-01-30  마포구  중국                  해외유입   퇴원  20-01
# 24264      3      6  2020-01-30  종로구   -              종로구 집단발병   퇴원  20-01
# 24265      2      5  2020-01-30  중랑구  중국                  해외유입   퇴원  20-01
# 24266      1      2  2020-01-24  강서구  중국                  해외유입   퇴원  20-01
#
#             년월일  월  주      년주    타지역     퇴원     사망     병원
# 0      21-01-31  1  4  2021-4   True  False  False   True
# 1      21-01-31  1  4  2021-4  False  False  False   True
# 2      21-01-31  1  4  2021-4  False  False  False   True
# 3      21-01-31  1  4  2021-4  False  False  False   True
# 4      21-01-31  1  4  2021-4   True  False  False   True
# ...         ... .. ..     ...    ...    ...    ...    ...
# 24262  20-01-31  1  5  2020-5  False   True  False  False
# 24263  20-01-30  1  5  2020-5  False   True  False  False
# 24264  20-01-30  1  5  2020-5  False   True  False  False
# 24265  20-01-30  1  5  2020-5  False   True  False  False
# 24266  20-01-24  1  4  2020-4  False   True  False  False
#
# [24267 rows x 16 columns]

# %%
print(df["퇴원"].value_counts())
df["퇴원"].value_counts(normalize=True)
# Out:
# True     20297
# False     3970
# Name: 퇴원, dtype: int64
# True     0.836403
# False    0.163597
# Name: 퇴원, dtype: float64

# %%
print(df["사망"].value_counts())
df["사망"].value_counts(normalize=True)
# Out:
# False    23942
# True       325
# Name: 사망, dtype: int64
# False    0.986607
# True     0.013393
# Name: 사망, dtype: float64

# %%
df[(df["퇴원"] == False) & (df["사망"] == False) & (df["타지역"] != True)].tail(5)
# Out:
#          연번     환자         확진일  거주지 여행력                         접촉력 조치상황  \
# 17764  6503  27936  2020-11-11  용산구   -                    감염경로 조사중  치료중
# 17879  6388  27596  2020-11-09  강서구   -                   기타 확진자 접촉  치료중
# 18372  5895  26209  2020-10-28  중랑구   -  기타 확진자 접촉\r\n[경기도 SRC재활병원]  치료중
# 18843  5424  24316  2020-10-06  중랑구   -                    감염경로 조사중  치료중
# 19513  4754  22411  2020-09-15  마포구   -             강남구 소재 대우디오빌플러스  치료중
#
#           년월       년월일   월   주       년주    타지역     퇴원     사망    병원
# 17764  20-11  20-11-11  11  46  2020-46  False  False  False  True
# 17879  20-11  20-11-09  11  46  2020-46  False  False  False  True
# 18372  20-10  20-10-28  10  44  2020-44  False  False  False  True
# 18843  20-10  20-10-06  10  41  2020-41  False  False  False  True
# 19513  20-09  20-09-15   9  38  2020-38  False  False  False  True
