# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\SANGMIN\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False)
plt.style.use("fivethirtyeight")

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
df = pd.read_csv("seoul_covid19.csv")
df
# Out:
#           연번     환자         확진일  거주지 여행력         접촉력 조치상황     년월       년월일  월  \
# 0      23459  75194  2021-01-24  타시도   -    감염경로 조사중  치료중  21-01  21-01-24  1
# 1      23458  75327  2021-01-24  관악구   -  타시도 확진자 접촉  치료중  21-01  21-01-24  1
# 2      23457  75378  2021-01-24  관악구   -   기타 확진자 접촉  치료중  21-01  21-01-24  1
# 3      23456  75369  2021-01-24  종로구   -   병원 및 요양시설  치료중  21-01  21-01-24  1
# 4      23455  75356  2021-01-24  강동구   -   기타 확진자 접촉  치료중  21-01  21-01-24  1
# ...      ...    ...         ...  ...  ..         ...  ...    ...       ... ..
# 23454      5      9  2020-01-31  성북구   -   기타 확진자 접촉   퇴원  20-01  20-01-31  1
# 23455      4      7  2020-01-30  마포구  중국        해외유입   퇴원  20-01  20-01-30  1
# 23456      3      6  2020-01-30  종로구   -    종로구 집단발병   퇴원  20-01  20-01-30  1
# 23457      2      5  2020-01-30  중랑구  중국        해외유입   퇴원  20-01  20-01-30  1
# 23458      1      2  2020-01-24  강서구  중국        해외유입   퇴원  20-01  20-01-24  1
#
#        주       년주
# 0      3  2021-03
# 1      3  2021-03
# 2      3  2021-03
# 3      3  2021-03
# 4      3  2021-03
# ...   ..      ...
# 23454  5  2020-05
# 23455  5  2020-05
# 23456  5  2020-05
# 23457  5  2020-05
# 23458  4  2020-04
#
# [23459 rows x 12 columns]

# %%
day_count = df["확진일"].value_counts().head(10)
day_count
# Out:
# 2020-12-17    586
# 2020-12-24    566
# 2020-12-28    525
# 2020-12-25    431
# 2020-12-16    426
# 2020-12-12    392
# 2020-12-29    387
# 2020-12-18    385
# 2020-12-15    380
# 2020-12-22    375
# Name: 확진일, dtype: int64

# %%
year_month = df["년월"].value_counts().sort_index()
year_month
# Out:
# 20-01        7
# 20-02       80
# 20-03      391
# 20-04      156
# 20-05      229
# 20-06      459
# 20-07      281
# 20-08     2415
# 20-09     1306
# 20-10      733
# 20-11     2903
# 20-12    10426
# 21-01     4073
# Name: 년월, dtype: int64

# %%
year_month_g = df["년월"].value_counts().sort_index().plot.bar(figsize=(15,4),rot=1)

# %%
year_month_g = df["년월"].value_counts().sort_index().plot.bar(figsize=(15,4),rot=1)
for i in range (len(year_month)):
    count = year_month.iloc[i]
    year_month_g.text(x=i-0.15,y=count+300,s=count)

# %%
week_count = df.groupby(["년월", "주"])["연번"].count()
week_count
# Out:
# 년월     주
# 20-01  4        1
#        5        6
# 20-02  5        1
#        6        4
#        7        2
#              ...
# 20-12  53    1633
# 21-01  1     1456
#        2     1002
#        3      846
#        53     769
# Name: 연번, Length: 64, dtype: int64

# %%
week_count_g = week_count.plot.barh(figsize=(15,25),rot=1,title="주차별 코로나 확진자 수")

# %%
import datetime

def GetWeekFirstDate(sourceDate):
    weekDayCount = sourceDate.weekday()
    targetDate = sourceDate - datetime.timedelta(days=weekDayCount);
    return targetDate

df['년주'] = df['확진일'].apply(lambda x : GetWeekFirstDate(datetime.datetime.strptime(x,'%Y-%m-%d')).strftime("%Y-%V"))

# %%
week_count = df.groupby(["년월", "년주"])["연번"].count()
week_count
# Out:
# 년월     년주
# 20-01  2020-04       1
#        2020-05       6
# 20-02  2020-05       1
#        2020-06       4
#        2020-07       2
#                   ...
# 20-12  2020-53    1633
# 21-01  2020-53     769
#        2021-01    1456
#        2021-02    1002
#        2021-03     846
# Name: 연번, Length: 64, dtype: int64

# %%
week_count_g = week_count.plot.barh(figsize=(15,25),rot=1,title="주차별 코로나 확진자 수")

# %%
df
# Out:
#           연번     환자         확진일  거주지 여행력         접촉력 조치상황     년월       년월일  월  \
# 0      23459  75194  2021-01-24  타시도   -    감염경로 조사중  치료중  21-01  21-01-24  1
# 1      23458  75327  2021-01-24  관악구   -  타시도 확진자 접촉  치료중  21-01  21-01-24  1
# 2      23457  75378  2021-01-24  관악구   -   기타 확진자 접촉  치료중  21-01  21-01-24  1
# 3      23456  75369  2021-01-24  종로구   -   병원 및 요양시설  치료중  21-01  21-01-24  1
# 4      23455  75356  2021-01-24  강동구   -   기타 확진자 접촉  치료중  21-01  21-01-24  1
# ...      ...    ...         ...  ...  ..         ...  ...    ...       ... ..
# 23454      5      9  2020-01-31  성북구   -   기타 확진자 접촉   퇴원  20-01  20-01-31  1
# 23455      4      7  2020-01-30  마포구  중국        해외유입   퇴원  20-01  20-01-30  1
# 23456      3      6  2020-01-30  종로구   -    종로구 집단발병   퇴원  20-01  20-01-30  1
# 23457      2      5  2020-01-30  중랑구  중국        해외유입   퇴원  20-01  20-01-30  1
# 23458      1      2  2020-01-24  강서구  중국        해외유입   퇴원  20-01  20-01-24  1
#
#        주       년주
# 0      3  2021-03
# 1      3  2021-03
# 2      3  2021-03
# 3      3  2021-03
# 4      3  2021-03
# ...   ..      ...
# 23454  5  2020-05
# 23455  5  2020-05
# 23456  5  2020-05
# 23457  5  2020-05
# 23458  4  2020-04
#
# [23459 rows x 12 columns]

# %%
df["확진일"] = pd.to_datetime(df["확진일"])

# %%
df["확진요일"] = df["확진일"].dt.dayofweek
df["확진요일"]
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 23454    4
# 23455    3
# 23456    3
# 23457    3
# 23458    4
# Name: 확진요일, Length: 23459, dtype: int64

# %%
df_week_day = df.groupby(["년주", "확진요일"])["연번"].count()
df_week_day = df_week_day.unstack()
df_week_day = df_week_day.fillna(0).astype(int)
df_week_day
# Out:
# 확진요일       0    1    2    3    4    5    6
# 년주
# 2020-04    0    0    0    0    1    0    0
# 2020-05    0    0    0    3    3    0    1
# 2020-06    0    0    2    2    0    0    0
# 2020-07    0    0    0    0    0    0    2
# 2020-08    0    0    2    5    2    5    3
# 2020-09    4   16   10    9   12    5    5
# 2020-10    6    0    7    1    7    7   10
# 2020-11   26   46   17   12    9    8    6
# 2020-12   11    6   11   17   17    8    6
# 2020-13    6   13   13   14   15   22   22
# 2020-14   19   24   16   20   20   20   10
# 2020-15    8   10   11    5    3    2    8
# 2020-16    3    5    1    2    2    1    1
# 2020-17    0    2    0    0    1    0    0
# 2020-18    4    0    0    1    1    2    0
# 2020-19    0    0    0    0   13   18   21
# 2020-20   11    8    5   12    6    4    1
# 2020-21    7    9    4    3    3    6    7
# 2020-22    8   20   24   19    9    6    2
# 2020-23   13   20   15   14   28   29   15
# 2020-24   18   13   19   25   30   12    8
# 2020-25   12   12   24   18   17   14    8
# 2020-26    4   11    8   17   17   14    7
# 2020-27    8    9   13   11    7   16    3
# 2020-28    3   11    7    8    8    7   13
# 2020-29    7    6    7    9    6   10    3
# 2020-30   21   17   12   20   11    7    9
# 2020-31    7    8    3    9    2    4    5
# 2020-32    9    6    9   10   16   13   13
# 2020-33    7   17   23   35   71  150   91
# 2020-34  128  152  134  127  127  147   97
# 2020-35  142  156  107  162  118  166   70
# 2020-36  103   87   65   46   56   58   44
# 2020-37   81   47   36   64   38   34   41
# 2020-38   36   50   80   39   32   20   23
# 2020-39   39   41   24   67   12   48    6
# 2020-40   26   36   30   21   24    8   19
# 2020-41   19   40   10   21   25   24   31
# 2020-42   20   26   21   19   18   19   16
# 2020-43   12   15   17   21   21   27   14
# 2020-44   20   31   33   50   46   45   25
# 2020-45   22   43   49   40   37   55   45
# 2020-46   36   44   53   74   69   85   71
# 2020-47   98   92  109  132  156  121  112
# 2020-48  133  142  212  203  177  156  158
# 2020-49  154  200  261  296  235  243  238
# 2020-50  231  259  252  258  364  392  219
# 2020-51  249  380  426  586  385  294  333
# 2020-52  327  375  349  566  431  344  300
# 2020-53  525  387  359  362  248  191  330
# 2021-01  194  260  298  191  187  186  140
# 2021-02  167  148  138  120  155  145  129
# 2021-03  102  146  122  114  127  133  102

# %%
df_week_day.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6], dtype='int64', name='확진요일')

# %%
dayofweek = "월 화 수 목 금 토 일"
dayofweek = dayofweek.split()
dayofweek
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
df_week_day.columns = dayofweek

# %%
week = df_week_day.sum(axis=1)
df_week_day["주당 확진자 수"] = week

# %%
week_avg = (a/7).astype(int)
df_week_day["주당 평균 확진자 수"] = week_avg 
df_week_day.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
#     #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col3 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row1_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col2 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row2_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col6 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row3_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col2 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col3 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col5 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col6 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col7 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row4_col8 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col1 {
#             background-color:  #eff6fc;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col2 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col3 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col4 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col5 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col6 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col7 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row5_col8 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col2 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col4 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_2f88c5ac_614d_11eb_933e_7cb27dd56893row6_col5 {
#             background-color:  #f4f9fe;
#             color:  #000000;

# %%
file_name = "analysis(1)"

# %%
df.to_csv(file_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-33-a7bca82e17e8> in <module>
# ----> 1 df.to_csv(file_name, index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'analysis(1)'
