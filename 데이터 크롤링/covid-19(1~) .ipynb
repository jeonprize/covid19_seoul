# %%
import pandas as pd

# %%
url="https://www.seoul.go.kr/coronaV/coronaStatus.do"

# %%
table=pd.read_html(url)

# %%
len(table)
# Out:
# 6

# %%
df=table[3]

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [연번, 환자, 확진일, 거주지, 여행력, 접촉력, 퇴원현황]
# Index: []

# %%
import requests

# %%
url="https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw=1"
url=f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc"
url=f"{url}&start=0&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1611043539751"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
response = requests.get(url)
data_json = response.json()
data_json
# Out:
# {'draw': 1,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>10000</p>",
#    '37131',
#    '2020-12-05',
#    '금천구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9999</p>",
#    '37141',
#    '2020-12-05',
#    '금천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9998</p>",
#    '37541',
#    '2020-12-05',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9997</p>",
#    '37542',
#    '2020-12-05',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9996</p>",
#    '37087',
#    '2020-12-05',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9995</p>",
#    '37073',
#    '2020-12-05',
#    '서초구',
#    '-',
#    '동작구 최비야 관련',
#    "<b class='status1'>퇴원</b>"],
# ...

# %%
records_total=data_json["recordsTotal"]
records_total
# Out:
# 10000

# %%
pd.DataFrame(data_json["data"])
# Out:
#                                    0      1           2    3  4  \
# 0   <p class='corona19_no'>10000</p>  37131  2020-12-05  금천구  -
# 1    <p class='corona19_no'>9999</p>  37141  2020-12-05  금천구  -
# 2    <p class='corona19_no'>9998</p>  37541  2020-12-05  송파구  -
# 3    <p class='corona19_no'>9997</p>  37542  2020-12-05  송파구  -
# 4    <p class='corona19_no'>9996</p>  37087  2020-12-05  서초구  -
# ..                               ...    ...         ...  ... ..
# 95   <p class='corona19_no'>9905</p>  36753  2020-12-04  강남구  -
# 96   <p class='corona19_no'>9904</p>  36734  2020-12-04  성동구  -
# 97   <p class='corona19_no'>9903</p>  36732  2020-12-04  서초구  -
# 98   <p class='corona19_no'>9902</p>  36751  2020-12-04  서초구  -
# 99   <p class='corona19_no'>9901</p>  36727  2020-12-04  은평구  -
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉  <b class='status1'>퇴원</b>
# 2        기타 확진자 접촉  <b class='status1'>퇴원</b>
# ...

# %%
end_page = round(records_total/100) + 1
end_page
# Out:
# 101

# %%
def get_seoul_covid19_100(page_num):
    start_num = (page_num - 1) * 100
    url=f"https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax_pre.php?draw={page_num}"
    url=f"{url}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc"
    url=f"{url}&start={start_num}&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1611043539751"
    
    response = requests.get(url)
    data_json = response.json()
    return data_json

# %%
get_seoul_covid19_100(1)
# Out:
# {'draw': 1,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>10000</p>",
#    '37131',
#    '2020-12-05',
#    '금천구',
#    '-',
#    '구로구 소재 보험회사 관련',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9999</p>",
#    '37141',
#    '2020-12-05',
#    '금천구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9998</p>",
#    '37541',
#    '2020-12-05',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9997</p>",
#    '37542',
#    '2020-12-05',
#    '송파구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9996</p>",
#    '37087',
#    '2020-12-05',
#    '서초구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>9995</p>",
#    '37073',
#    '2020-12-05',
#    '서초구',
#    '-',
#    '동작구 최비야 관련',
#    "<b class='status1'>퇴원</b>"],
# ...

# %%
get_seoul_covid19_100(100)
# Out:
# {'draw': 100,
#  'recordsTotal': 10000,
#  'recordsFiltered': 10000,
#  'data': [["<p class='corona19_no'>100</p>",
#    '5377',
#    '2020-03-04',
#    '동대문구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>99</p>",
#    '5592',
#    '2020-03-04',
#    '동대문구',
#    '-',
#    '동대문관련(교회pc방)',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>98</p>",
#    '4645',
#    '2020-03-02',
#    '도봉구',
#    '-',
#    '감염경로 조사중',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>97</p>",
#    '4517',
#    '2020-03-02',
#    '강남구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>96</p>",
#    '4743',
#    '2020-03-02',
#    '서초구',
#    '-',
#    '감염경로 조사중',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>95</p>",
#    '4224',
#    '2020-03-02',
#    '영등포구',
#    '-',
#    '성동구 아파트 관리사무소',
#    "<b class='status1'>퇴원</b>"],
#   ["<p class='corona19_no'>94</p>",
# ...

# %%
import time
from tqdm import trange

# %%
def get_multi_page_list(start_page, end_page):
    
    page_list = []
    for page_num in trange(start_page, end_page + 1):
        one_page = get_seoul_covid19_100(page_num)
        if len(one_page["data"]) > 0 :
            one_page = pd.DataFrame(one_page["data"])
            page_list.append(one_page)
            time.sleep(0.7)
        else :
            return page_list
    return page_list

# %%
end_page
# Out:
# 101

# %%
start_page = 1
page_list = get_multi_page_list(start_page, end_page)
page_list[:1]
# Out:
#  99%|███████████████████████████████████████████████████████████████████████████████▏| 100/101 [02:03<00:01,  1.14s/it]
# [                                   0      1           2    3  4  \
#  0   <p class='corona19_no'>10000</p>  37131  2020-12-05  금천구  -
#  1    <p class='corona19_no'>9999</p>  37141  2020-12-05  금천구  -
#  2    <p class='corona19_no'>9998</p>  37541  2020-12-05  송파구  -
#  3    <p class='corona19_no'>9997</p>  37542  2020-12-05  송파구  -
#  4    <p class='corona19_no'>9996</p>  37087  2020-12-05  서초구  -
#  ..                               ...    ...         ...  ... ..
#  95   <p class='corona19_no'>9905</p>  36753  2020-12-04  강남구  -
#  96   <p class='corona19_no'>9904</p>  36734  2020-12-04  성동구  -
#  97   <p class='corona19_no'>9903</p>  36732  2020-12-04  서초구  -
#  98   <p class='corona19_no'>9902</p>  36751  2020-12-04  서초구  -
#  99   <p class='corona19_no'>9901</p>  36727  2020-12-04  은평구  -
#
#                   5                          6
# ...

# %%
df_all = pd.concat(page_list)
df_all
# Out:
#                                    0      1           2    3   4  \
# 0   <p class='corona19_no'>10000</p>  37131  2020-12-05  금천구   -
# 1    <p class='corona19_no'>9999</p>  37141  2020-12-05  금천구   -
# 2    <p class='corona19_no'>9998</p>  37541  2020-12-05  송파구   -
# 3    <p class='corona19_no'>9997</p>  37542  2020-12-05  송파구   -
# 4    <p class='corona19_no'>9996</p>  37087  2020-12-05  서초구   -
# ..                               ...    ...         ...  ...  ..
# 95      <p class='corona19_no'>5</p>      9  2020-01-31  성북구   -
# 96      <p class='corona19_no'>4</p>      7  2020-01-30  마포구  중국
# 97      <p class='corona19_no'>3</p>      6  2020-01-30  종로구   -
# 98      <p class='corona19_no'>2</p>      5  2020-01-30  중랑구  중국
# 99      <p class='corona19_no'>1</p>      2  2020-01-24  강서구  중국
#
#                  5                          6
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉  <b class='status1'>퇴원</b>
# ...

# %%
cols = df.columns.tolist()
cols
# Out:
# ['연번', '환자', '확진일', '거주지', '여행력', '접촉력', '퇴원현황']

# %%
df_all.columns = cols
df_all
# Out:
#                                   연번     환자         확진일  거주지 여행력  \
# 0   <p class='corona19_no'>10000</p>  37131  2020-12-05  금천구   -
# 1    <p class='corona19_no'>9999</p>  37141  2020-12-05  금천구   -
# 2    <p class='corona19_no'>9998</p>  37541  2020-12-05  송파구   -
# 3    <p class='corona19_no'>9997</p>  37542  2020-12-05  송파구   -
# 4    <p class='corona19_no'>9996</p>  37087  2020-12-05  서초구   -
# ..                               ...    ...         ...  ...  ..
# 95      <p class='corona19_no'>5</p>      9  2020-01-31  성북구   -
# 96      <p class='corona19_no'>4</p>      7  2020-01-30  마포구  중국
# 97      <p class='corona19_no'>3</p>      6  2020-01-30  종로구   -
# 98      <p class='corona19_no'>2</p>      5  2020-01-30  중랑구  중국
# 99      <p class='corona19_no'>1</p>      2  2020-01-24  강서구  중국
#
#                접촉력                       퇴원현황
# 0   구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1        기타 확진자 접촉  <b class='status1'>퇴원</b>
# ...

# %%
df_all.shape
# Out:
# (10000, 7)

# %%
url_1 = "https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw=1"
url_1 = f"{url_1}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc"
url_1 = f"{url_1}&start=0&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1611400343598"

# %%
requests.get(url_1)
# Out:
# <Response [200]>

# %%
response_1 = requests.get(url_1)
data_json_1 = response_1.json()
data_json_1
# Out:
# {'draw': 1,
#  'recordsTotal': 13459,
#  'recordsFiltered': 13459,
#  'data': [["<p class='corona19_no'>23459</p>",
#    '75194',
#    '2021-01-24',
#    '타시도',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23458</p>",
#    '75327',
#    '2021-01-24',
#    '관악구',
#    '-',
#    '타시도 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23457</p>",
#    '75378',
#    '2021-01-24',
#    '관악구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23456</p>",
#    '75369',
#    '2021-01-24',
#    '종로구',
#    '-',
#    '병원 및 요양시설',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23455</p>",
#    '75356',
#    '2021-01-24',
#    '강동구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23454</p>",
#    '75362',
#    '2021-01-24',
#    '관악구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23453</p>",
#    '75357',
#    '2021-01-24',
# ...

# %%
recordstotal_1 = data_json_1["recordsTotal"]

# %%
pd.DataFrame(data_json_1["data"])
# Out:
#                                    0      1           2    3  4  \
# 0   <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도  -
# 1   <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구  -
# 2   <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구  -
# 3   <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구  -
# 4   <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구  -
# ..                               ...    ...         ...  ... ..
# 95  <p class='corona19_no'>23364</p>  75162  2021-01-24  동작구  -
# 96  <p class='corona19_no'>23363</p>  75237  2021-01-24  관악구  -
# 97  <p class='corona19_no'>23362</p>  75135  2021-01-24  성동구  -
# 98  <p class='corona19_no'>23361</p>  75114  2021-01-24  강남구  -
# 99  <p class='corona19_no'>23360</p>  75119  2021-01-24  강남구  -
#
#                 5                 6
# 0        감염경로 조사중  <b class=''></b>
# 1      타시도 확진자 접촉  <b class=''></b>
# 2       기타 확진자 접촉  <b class=''></b>
# 3       병원 및 요양시설  <b class=''></b>
# ...

# %%
end_page_1 = round(recordstotal_1 / 100) + 1
end_page_1
# Out:
# 136

# %%
def get_seoul_covid19_100_1(page_num_1):
    start_num_1 = (page_num_1 - 1) * 100
    url_1 = f"https://news.seoul.go.kr/api/27/getCorona19Status/get_status_ajax.php?draw={page_num_1}"
    url_1 = f"{url_1}&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=desc"
    url_1 = f"{url_1}&start={start_num_1}&length=100&search%5Bvalue%5D=&search%5Bregex%5D=true&_=1611400343598"
    
    response_1 = requests.get(url_1)
    data_json_1 = response_1.json()
    return data_json_1

# %%
get_seoul_covid19_100_1(2)
# Out:
# {'draw': 2,
#  'recordsTotal': 13459,
#  'recordsFiltered': 13459,
#  'data': [["<p class='corona19_no'>23359</p>",
#    '75144',
#    '2021-01-24',
#    '마포구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23358</p>",
#    '75145',
#    '2021-01-24',
#    '마포구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23357</p>",
#    '75084',
#    '2021-01-23',
#    '서초구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23356</p>",
#    '75079',
#    '2021-01-23',
#    '마포구',
#    '-',
#    '감염경로 조사중',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23355</p>",
#    '75019',
#    '2021-01-23',
#    '영등포구',
#    '-',
#    '기타 확진자 접촉',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23354</p>",
#    '74931',
#    '2021-01-23',
#    '기타',
#    '파키스탄',
#    '해외유입',
#    "<b class=''></b>"],
#   ["<p class='corona19_no'>23353</p>",
#    '74927',
#    '2021-01-23',
#    '도봉구',
# ...

# %%
import time
from tqdm import trange

# %%
def get_multi_page_list_1(start_page_1, end_page_1):
    
    page_list_1 = []
    for page_num_1 in trange(start_page_1, end_page_1 + 1):
        one_page_1 = get_seoul_covid19_100_1(page_num_1)
        if len(one_page_1) > 0 :
            one_page_1 = pd.DataFrame(one_page_1["data"])
            page_list_1.append(one_page_1)
            time.sleep(0.7)
        else :
            return page_list_1
    return page_list_1

# %%
end_page_1
# Out:
# 136

# %%
start_page_1 = 1
page_list_1 = get_multi_page_list_1(start_page_1, end_page_1)
page_list_1[:3]
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 136/136 [02:36<00:00,  1.15s/it]
# [                                   0      1           2    3  4  \
#  0   <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도  -
#  1   <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구  -
#  2   <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구  -
#  3   <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구  -
#  4   <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구  -
#  ..                               ...    ...         ...  ... ..
#  95  <p class='corona19_no'>23364</p>  75162  2021-01-24  동작구  -
#  96  <p class='corona19_no'>23363</p>  75237  2021-01-24  관악구  -
#  97  <p class='corona19_no'>23362</p>  75135  2021-01-24  성동구  -
#  98  <p class='corona19_no'>23361</p>  75114  2021-01-24  강남구  -
#  99  <p class='corona19_no'>23360</p>  75119  2021-01-24  강남구  -
#
#                  5                 6
# ...

# %%
df_all_1 = pd.concat(page_list_1)
df_all_1
# Out:
#                                    0      1           2    3  4  \
# 0   <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도  -
# 1   <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구  -
# 2   <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구  -
# 3   <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구  -
# 4   <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구  -
# ..                               ...    ...         ...  ... ..
# 54  <p class='corona19_no'>10005</p>  37079  2020-12-05  성북구  -
# 55  <p class='corona19_no'>10004</p>  36987  2020-12-05  구로구  -
# 56  <p class='corona19_no'>10003</p>  37010  2020-12-05  노원구  -
# 57  <p class='corona19_no'>10002</p>  37094  2020-12-05  노원구  -
# 58  <p class='corona19_no'>10001</p>  37213  2020-12-05  금천구  -
#
#                  5                          6
# 0         감염경로 조사중           <b class=''></b>
# 1       타시도 확진자 접촉           <b class=''></b>
# 2        기타 확진자 접촉           <b class=''></b>
# ...

# %%
df_all_1.columns = cols
df_all_1
# Out:
#                                   연번     환자         확진일  거주지 여행력  \
# 0   <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도   -
# 1   <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구   -
# 2   <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구   -
# 3   <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구   -
# 4   <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구   -
# ..                               ...    ...         ...  ...  ..
# 54  <p class='corona19_no'>10005</p>  37079  2020-12-05  성북구   -
# 55  <p class='corona19_no'>10004</p>  36987  2020-12-05  구로구   -
# 56  <p class='corona19_no'>10003</p>  37010  2020-12-05  노원구   -
# 57  <p class='corona19_no'>10002</p>  37094  2020-12-05  노원구   -
# 58  <p class='corona19_no'>10001</p>  37213  2020-12-05  금천구   -
#
#                접촉력                       퇴원현황
# 0         감염경로 조사중           <b class=''></b>
# 1       타시도 확진자 접촉           <b class=''></b>
# ...

# %%
df_all.shape
# Out:
# (10000, 7)

# %%
df_all_1.shape
# Out:
# (13459, 7)

# %%
df_all.head()
# Out:
#                                  연번     환자         확진일  거주지 여행력  \
# 0  <p class='corona19_no'>10000</p>  37131  2020-12-05  금천구   -
# 1   <p class='corona19_no'>9999</p>  37141  2020-12-05  금천구   -
# 2   <p class='corona19_no'>9998</p>  37541  2020-12-05  송파구   -
# 3   <p class='corona19_no'>9997</p>  37542  2020-12-05  송파구   -
# 4   <p class='corona19_no'>9996</p>  37087  2020-12-05  서초구   -
#
#               접촉력                       퇴원현황
# 0  구로구 소재 보험회사 관련  <b class='status1'>퇴원</b>
# 1       기타 확진자 접촉  <b class='status1'>퇴원</b>
# 2       기타 확진자 접촉  <b class='status1'>퇴원</b>
# 3       기타 확진자 접촉  <b class='status1'>퇴원</b>
# 4       기타 확진자 접촉  <b class='status1'>퇴원</b>

# %%
df_all_1.head()
# Out:
#                                  연번     환자         확진일  거주지 여행력         접촉력  \
# 0  <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도   -    감염경로 조사중
# 1  <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구   -  타시도 확진자 접촉
# 2  <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구   -   기타 확진자 접촉
# 3  <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구   -   병원 및 요양시설
# 4  <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구   -   기타 확진자 접촉
#
#                퇴원현황
# 0  <b class=''></b>
# 1  <b class=''></b>
# 2  <b class=''></b>
# 3  <b class=''></b>
# 4  <b class=''></b>

# %%
covid19 = pd.concat([df_all_1,df_all])
covid19
# Out:
#                                   연번     환자         확진일  거주지 여행력         접촉력  \
# 0   <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도   -    감염경로 조사중
# 1   <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구   -  타시도 확진자 접촉
# 2   <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구   -   기타 확진자 접촉
# 3   <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구   -   병원 및 요양시설
# 4   <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구   -   기타 확진자 접촉
# ..                               ...    ...         ...  ...  ..         ...
# 95      <p class='corona19_no'>5</p>      9  2020-01-31  성북구   -   기타 확진자 접촉
# 96      <p class='corona19_no'>4</p>      7  2020-01-30  마포구  중국        해외유입
# 97      <p class='corona19_no'>3</p>      6  2020-01-30  종로구   -    종로구 집단발병
# 98      <p class='corona19_no'>2</p>      5  2020-01-30  중랑구  중국        해외유입
# 99      <p class='corona19_no'>1</p>      2  2020-01-24  강서구  중국        해외유입
#
#                          퇴원현황
# ...

# %%
covid19.head()
# Out:
#                                  연번     환자         확진일  거주지 여행력         접촉력  \
# 0  <p class='corona19_no'>23459</p>  75194  2021-01-24  타시도   -    감염경로 조사중
# 1  <p class='corona19_no'>23458</p>  75327  2021-01-24  관악구   -  타시도 확진자 접촉
# 2  <p class='corona19_no'>23457</p>  75378  2021-01-24  관악구   -   기타 확진자 접촉
# 3  <p class='corona19_no'>23456</p>  75369  2021-01-24  종로구   -   병원 및 요양시설
# 4  <p class='corona19_no'>23455</p>  75356  2021-01-24  강동구   -   기타 확진자 접촉
#
#                퇴원현황
# 0  <b class=''></b>
# 1  <b class=''></b>
# 2  <b class=''></b>
# 3  <b class=''></b>
# 4  <b class=''></b>

# %%
covid19.tail()
# Out:
#                               연번 환자         확진일  거주지 여행력        접촉력  \
# 95  <p class='corona19_no'>5</p>  9  2020-01-31  성북구   -  기타 확진자 접촉
# 96  <p class='corona19_no'>4</p>  7  2020-01-30  마포구  중국       해외유입
# 97  <p class='corona19_no'>3</p>  6  2020-01-30  종로구   -   종로구 집단발병
# 98  <p class='corona19_no'>2</p>  5  2020-01-30  중랑구  중국       해외유입
# 99  <p class='corona19_no'>1</p>  2  2020-01-24  강서구  중국       해외유입
#
#                          퇴원현황
# 95  <b class='status1'>퇴원</b>
# 96  <b class='status1'>퇴원</b>
# 97  <b class='status1'>퇴원</b>
# 98  <b class='status1'>퇴원</b>
# 99  <b class='status1'>퇴원</b>
